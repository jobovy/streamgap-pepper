# %%
import os, os.path
from galpy.util import bovy_plot
# %pylab inline
from matplotlib.ticker import NullFormatter
save_figures= False
# Out:
# /Users/bovy/anaconda/envs/py27/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
#
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Some figures to illustrate how to evaluate the peppered stream DF

# %% [markdown]
# ## Direct evaluation of $p(\Delta \Omega_\parallel,\Delta \theta_\parallel)$

# %%
bovy_plot.bovy_print(axes_labelsize=18.,xtick_labelsize=14.,ytick_labelsize=14.)
figsize(8,18)
nullfmt   = NullFormatter()         # no labels
legendsize= 20
subplot(5,1,1)
bovy_plot.bovy_plot([1.3],[0.17],color='k',marker='o',
                    xrange=[-0.1,1.5],
                    yrange=[0.,0.2],
                    xlabel=r'$\Delta\theta_\parallel$',
                    ylabel=r'$\Delta\Omega_\parallel$',gcf=True)
gca().xaxis.set_major_formatter(nullfmt)
gca().yaxis.set_major_formatter(nullfmt)
bovy_plot.bovy_text(0.03,0.17,r'$\mathrm{if}\ t^1_i < \Delta \theta_\parallel/\Delta \Omega_\parallel$',
                   size=legendsize)
bovy_plot.bovy_text(1.15,0.14,r'$(\Delta \Omega_\parallel,\Delta \theta_\parallel)$',
                   size=legendsize)
bovy_plot.bovy_text(1.,0.175,r'$\Delta t = t^1_i$',
                   size=legendsize)
arrow(1.25,0.17,-0.25,0.,color='k',head_width=.01,head_length=0.1,width=.001)
plot([0.85],[0.17],'ko')
bovy_plot.bovy_text(0.55,0.16,r'$(\Delta \Omega_\parallel,\Delta \theta^1_\parallel)$',
                   size=legendsize)
axvline(color='k',linestyle='--')
subplot(5,1,2)
bovy_plot.bovy_plot([1.3],[0.17],color='k',marker='o',
                    xrange=[-0.1,1.5],
                    yrange=[0.,0.2],
                    xlabel=r'$\Delta\theta_\parallel$',
                    ylabel=r'$\Delta\Omega_\parallel$',gcf=True)
arrow(1.25,0.17,-0.25,0.,color='k',head_width=.01,head_length=0.1,width=.001)
plot([0.85],[0.17],'ko')
bovy_plot.bovy_text(0.55,0.16,r'$(\Delta \Omega_\parallel,\Delta \theta^1_\parallel)$',
                   size=legendsize)
bovy_plot.bovy_text(.875,0.125,r'$-\delta \Omega^{g,1}_\parallel(\Delta \theta^1_\parallel)$',
                   size=legendsize)
arrow(0.85,0.16,0.,-0.05,color='k',head_width=.05,head_length=0.02)
plot([0.85],[0.0825],'ko')
bovy_plot.bovy_text(0.87,0.058,r'$(\Delta \Omega^1_\parallel,\Delta \theta^1_\parallel)$',
                   size=legendsize)
gca().xaxis.set_major_formatter(nullfmt)
gca().yaxis.set_major_formatter(nullfmt)
axvline(color='k',linestyle='--')
subplot(5,1,3)
bovy_plot.bovy_plot([1.3],[0.17],color='k',marker='o',
                    xrange=[-0.1,1.5],
                    yrange=[0.,0.2],
                    xlabel=r'$\Delta\theta_\parallel$',
                    ylabel=r'$\Delta\Omega_\parallel$',gcf=True)
arrow(1.25,0.17,-0.25,0.,color='k',head_width=.01,head_length=0.1,width=.001)
plot([0.85],[0.17],'ko')
arrow(0.85,0.16,0.,-0.05,color='k',head_width=.05,head_length=0.02)
plot([0.85],[0.0825],'ko')
bovy_plot.bovy_text(0.87,0.058,r'$(\Delta \Omega^1_\parallel,\Delta \theta^1_\parallel)$',
                   size=legendsize)
bovy_plot.bovy_text(.45,0.06,r'$\Delta t = t^2_i-t^1_i$',
                   size=legendsize)
arrow(0.8,0.0825,-0.35,0.,color='k',head_width=.01,head_length=0.1,width=.001)
plot([0.3],[0.0825],'ko')
bovy_plot.bovy_text(0.01,0.062,r'$(\Delta \Omega^1_\parallel,\Delta \theta^2_\parallel)$',
                   size=legendsize)
gca().xaxis.set_major_formatter(nullfmt)
gca().yaxis.set_major_formatter(nullfmt)
bovy_plot.bovy_text(0.03,0.17,r'$\mathrm{if}\ t^2_i-t^1_i < \Delta \theta^1_\parallel/\Delta \Omega^1_\parallel$',
                   size=legendsize)
axvline(color='k',linestyle='--')
subplot(5,1,4)
bovy_plot.bovy_plot([1.3],[0.17],color='k',marker='o',
                    xrange=[-0.1,1.5],
                    yrange=[0.,0.2],
                    xlabel=r'$\Delta\theta_\parallel$',
                    ylabel=r'$\Delta\Omega_\parallel$',gcf=True)
arrow(1.25,0.17,-0.25,0.,color='k',head_width=.01,head_length=0.1,width=.001)
plot([0.85],[0.17],'ko')
arrow(0.85,0.16,0.,-0.05,color='k',head_width=.05,head_length=0.02)
plot([0.85],[0.0825],'ko')
arrow(0.8,0.0825,-0.35,0.,color='k',head_width=.01,head_length=0.1,width=.001)
plot([0.3],[0.0825],'ko')
bovy_plot.bovy_text(0.01,0.062,r'$(\Delta \Omega^1_\parallel,\Delta \theta^2_\parallel)$',
                   size=legendsize)
bovy_plot.bovy_text(.325,0.1,r'$-\delta \Omega^{g,2}_\parallel(\Delta \theta^2_\parallel)$',
                   size=legendsize)
arrow(0.3,0.0925,0.,+0.035,color='k',head_width=.05,head_length=0.02)
plot([0.3],[0.155],'ko')
bovy_plot.bovy_text(0.325,0.15,r'$(\Delta \Omega^2_\parallel,\Delta \theta^2_\parallel)$',
                   size=legendsize)
gca().xaxis.set_major_formatter(nullfmt)
gca().yaxis.set_major_formatter(nullfmt)
axvline(color='k',linestyle='--')
subplot(5,1,5)
bovy_plot.bovy_plot([1.3],[0.17],color='k',marker='o',
                    xrange=[-0.1,1.5],
                    yrange=[0.,0.2],
                    xlabel=r'$\Delta\theta_\parallel$',
                    ylabel=r'$\Delta\Omega_\parallel$',gcf=True)
arrow(1.25,0.17,-0.25,0.,color='k',head_width=.01,head_length=0.1,width=.001)
plot([0.85],[0.17],'ko')
arrow(0.85,0.16,0.,-0.05,color='k',head_width=.05,head_length=0.02)
plot([0.85],[0.0825],'ko')
arrow(0.8,0.0825,-0.35,0.,color='k',head_width=.01,head_length=0.1,width=.001)
plot([0.3],[0.0825],'ko')
arrow(0.3,0.0925,0.,+0.035,color='k',head_width=.05,head_length=0.02)
plot([0.3],[0.155],'ko')
bovy_plot.bovy_text(0.325,0.15,r'$(\Delta \Omega^2_\parallel,\Delta \theta^2_\parallel)$',
                   size=legendsize)
arrow(0.25,0.155,-0.125,0.,color='k',head_width=.01,head_length=0.1,width=.001)
plot([0.],[0.155],'ko')
bovy_plot.bovy_text(0.02,0.17,r'$\Delta t = t_s-t^2_i$',
                   size=legendsize)
gca().xaxis.set_major_formatter(nullfmt)
gca().yaxis.set_major_formatter(nullfmt)
axvline(color='k',linestyle='--')
tight_layout()
if save_figures:
    bovy_plot.bovy_end_print(os.path.join(os.getenv('PAPERSDIR'),'2016-stream-stats','illustrate_pOa.pdf'))

# %%
bovy_plot.bovy_print(axes_labelsize=18.,xtick_labelsize=14.,ytick_labelsize=14.)
figsize(8,18)
nullfmt   = NullFormatter()         # no labels
legendsize= 20
subplot(5,1,1)
bovy_plot.bovy_text(r'$\mathrm{present\ time}$',top_left=True,size=legendsize)
bovy_plot.bovy_text(r'$t=0$',bottom_left=True,size=legendsize)
bovy_plot.bovy_plot([1.3,1.3],[0.18,0.02],'k-',lw=2.,
                    xrange=[-0.1,1.5],
                    yrange=[0.,0.2],
                    xlabel=r'$\Delta\theta_\parallel$',
                    ylabel=r'$\Delta\Omega_\parallel$',gcf=True)
plot([0.6,0.8,1.,1.2],[0.1,0.14,0.06,0.1],'-o',color='0.5',lw=2.,ms=10.)
plot([0.55,1.25],[0.1,0.1],'-',color='0.5',lw=1.)
plot([0.2,0.4,0.6,0.8],[0.1,0.12,0.07,0.1],'--o',color='0.5',lw=2.,ms=7.)
plot([0.15,0.85],[0.1,0.1],'-',color='0.5',lw=1.)
gca().xaxis.set_major_formatter(nullfmt)
gca().yaxis.set_major_formatter(nullfmt)
subplot(5,1,2)
bovy_plot.bovy_text(r'$\mathrm{rewind\ to\ last\ impact}$',top_left=True,size=legendsize)
bovy_plot.bovy_text(r'$t=t^1_i-\epsilon$',bottom_left=True,size=legendsize)
bovy_plot.bovy_plot([0.6,0.8,1.,1.2],[0.18,0.16/-0.6*(0.8-0.6)+0.18,0.16/-0.6*(1.-0.6)+0.18,0.02],'k-o',lw=2.,ms=10.,
                    xrange=[-0.1,1.5],
                    yrange=[0.,0.2],
                    xlabel=r'$\Delta\theta_\parallel$',
                    ylabel=r'$\Delta\Omega_\parallel$',gcf=True)
plot([0.6,1.3],[0.18,0.18],'--',color='0.5')
plot([0.8,1.3],[0.16/-0.6*(0.8-0.6)+0.18,0.16/-0.6*(0.8-0.6)+0.18],'--',color='0.5')
plot([1.0,1.3],[0.16/-0.6*(1.-0.6)+0.18,0.16/-0.6*(1.-0.6)+0.18],'--',color='0.5')
plot([1.2,1.3],[0.02,0.02],'--',color='0.5')
plot([1.3,1.3],[0.18,0.02],'k-',lw=2.)
plot([0.6,0.8,1.,1.2],[0.1,0.14,0.06,0.1],'-o',color='0.5',lw=2.,ms=10.)
plot([0.55,1.25],[0.1,0.1],'-',color='0.5',lw=1.)
plot([0.2,0.4,0.6,0.8],[0.1,0.12,0.07,0.1],'--o',color='0.5',lw=2.,ms=7.)
plot([0.15,0.85],[0.1,0.1],'-',color='0.5',lw=1.)
gca().xaxis.set_major_formatter(nullfmt)
gca().yaxis.set_major_formatter(nullfmt)
subplot(5,1,3)
bovy_plot.bovy_text(r'$\mathrm{undo\ last\ impact}$',top_left=True,size=legendsize)
bovy_plot.bovy_text(r'$t=t^1_i+\epsilon$',bottom_left=True,size=legendsize)
bovy_plot.bovy_plot([0.6,0.8,1.,1.2],[0.18,0.04+0.16/-0.6*(0.8-0.6)+0.18,-0.04+0.16/-0.6*(1.-0.6)+0.18,0.02],'k-o',
                    lw=2.,ms=10.,
                    xrange=[-0.1,1.5],
                    yrange=[0.,0.2],
                    xlabel=r'$\Delta\theta_\parallel$',
                    ylabel=r'$\Delta\Omega_\parallel$',gcf=True)
plot([0.2,0.4,0.6,0.8],[0.1,0.12,0.07,0.1],'--o',color='0.5',lw=2.,ms=7.)
plot([0.15,0.85],[0.1,0.1],'-',color='0.5',lw=1.)
gca().xaxis.set_major_formatter(nullfmt)
gca().yaxis.set_major_formatter(nullfmt)
subplot(5,1,4)
bovy_plot.bovy_text(r'$\mathrm{rewind\ until\ previous\ impact}$',top_right=True,size=legendsize)
bovy_plot.bovy_text(r'$t=t^2_i-\epsilon$',bottom_left=True,size=legendsize)
bovy_plot.bovy_plot([0.1,0.35,0.85,1.1],[0.18,0.04+0.16/-0.6*(0.8-0.6)+0.18,-0.04+0.16/-0.6*(1.-0.6)+0.18,0.02],'k-o',
                    lw=2.,ms=10.,
                    xrange=[-0.1,1.5],
                    yrange=[0.,0.2],
                    xlabel=r'$\Delta\theta_\parallel$',
                    ylabel=r'$\Delta\Omega_\parallel$',gcf=True)
plot([0.2,0.4,0.6,0.8],[(0.04+0.16/-0.6*(0.8-0.6)+0.18-0.18)/(0.25)*(0.2-0.1)+0.18,
               (-0.04+0.16/-0.6*(1.-0.6)+0.18-(0.04+0.16/-0.6*(0.8-0.6)+0.18))/0.5*(0.4-0.35)+0.04+0.16/-0.6*(0.8-0.6)+0.18,
               (-0.04+0.16/-0.6*(1.-0.6)+0.18-(0.04+0.16/-0.6*(0.8-0.6)+0.18))/0.5*(0.6-0.35)+0.04+0.16/-0.6*(0.8-0.6)+0.18,
               (-0.04+0.16/-0.6*(1.-0.6)+0.18-(0.04+0.16/-0.6*(0.8-0.6)+0.18))/0.5*(0.8-0.35)+0.04+0.16/-0.6*(0.8-0.6)+0.18],
     'ko',ms=7.)
plot([0.6,0.8,1.,1.2],[0.18,0.04+0.16/-0.6*(0.8-0.6)+0.18,-0.04+0.16/-0.6*(1.-0.6)+0.18,0.02],'k-o',
                    lw=2.,ms=10.)
plot([0.1,0.6],[0.18,0.18],'--',color='0.5')
plot([0.35,0.8],[0.04+0.16/-0.6*(0.8-0.6)+0.18,0.04+0.16/-0.6*(0.8-0.6)+0.18],'--',color='0.5')
plot([0.85,1.],[-0.04+0.16/-0.6*(1.-0.6)+0.18,-0.04+0.16/-0.6*(1.-0.6)+0.18],'--',color='0.5')
plot([1.1,1.2],[0.02,0.02],'--',color='0.5')
plot([0.2,0.4,0.6,0.8],[0.1,0.12,0.07,0.1],'--o',color='0.5',lw=2.,ms=7.)
plot([0.15,0.85],[0.1,0.1],'-',color='0.5',lw=1.)
gca().xaxis.set_major_formatter(nullfmt)
gca().yaxis.set_major_formatter(nullfmt)
subplot(5,1,5)
bovy_plot.bovy_text(r'$\mathrm{undo\ previous\ impact}$'+'\n'+r'$\mathrm{continue\ until\ all\ impacts\ undone}$',
                    top_right=True,size=legendsize)
bovy_plot.bovy_text(r'$t=t^2_i+\epsilon$',bottom_left=True,size=legendsize)
bovy_plot.bovy_plot([0.1,0.2],[0.18,(0.04+0.16/-0.6*(0.8-0.6)+0.18-0.18)/(0.25)*(0.2-0.1)+0.18],'k-',
                    xrange=[-0.1,1.5],
                    yrange=[0.,0.2],
                    xlabel=r'$\Delta\theta_\parallel$',
                    ylabel=r'$\Delta\Omega_\parallel$',gcf=True)
plot([0.1],[0.18],'ko',ms=10.)
plot([0.2],[(0.04+0.16/-0.6*(0.8-0.6)+0.18-0.18)/(0.25)*(0.2-0.1)+0.18],'ko',ms=7.)
plot([0.2,0.35],[(0.04+0.16/-0.6*(0.8-0.6)+0.18-0.18)/(0.25)*(0.2-0.1)+0.18,
                0.04+0.16/-0.6*(0.8-0.6)+0.18+0.015],'k-')
plot([0.2],[(0.04+0.16/-0.6*(0.8-0.6)+0.18-0.18)/(0.25)*(0.2-0.1)+0.18],'ko',ms=7.)
plot([0.35],[0.04+0.16/-0.6*(0.8-0.6)+0.18+0.015],'ko',ms=10.)
plot([0.35,0.4],[0.04+0.16/-0.6*(0.8-0.6)+0.18+0.015,
                (-0.04+0.16/-0.6*(1.-0.6)+0.18-(0.04+0.16/-0.6*(0.8-0.6)+0.18))/0.5*(0.4-0.35)+0.04+0.16/-0.6*(0.8-0.6)+0.18+0.02],
    'k-')
plot([0.35],[0.04+0.16/-0.6*(0.8-0.6)+0.18+0.015],'ko',ms=10.)
plot([0.4],[(-0.04+0.16/-0.6*(1.-0.6)+0.18-(0.04+0.16/-0.6*(0.8-0.6)+0.18))/0.5*(0.4-0.35)+0.04+0.16/-0.6*(0.8-0.6)+0.18+0.02],
     'ko',ms=7.)
plot([0.4,0.6,0.8],[(-0.04+0.16/-0.6*(1.-0.6)+0.18-(0.04+0.16/-0.6*(0.8-0.6)+0.18))/0.5*(0.4-0.35)+0.04+0.16/-0.6*(0.8-0.6)+0.18+0.02,
                    (-0.04+0.16/-0.6*(1.-0.6)+0.18-(0.04+0.16/-0.6*(0.8-0.6)+0.18))/0.5*(0.6-0.35)+0.04+0.16/-0.6*(0.8-0.6)+0.18-0.03,
                   (-0.04+0.16/-0.6*(1.-0.6)+0.18-(0.04+0.16/-0.6*(0.8-0.6)+0.18))/0.5*(0.8-0.35)+0.04+0.16/-0.6*(0.8-0.6)+0.18],
     'k-o',ms=7.)
plot([0.8,0.85],[(-0.04+0.16/-0.6*(1.-0.6)+0.18-(0.04+0.16/-0.6*(0.8-0.6)+0.18))/0.5*(0.8-0.35)+0.04+0.16/-0.6*(0.8-0.6)+0.18,
                 -0.04+0.16/-0.6*(1.-0.6)+0.18],'k-')
plot([0.85,1.1],[-0.04+0.16/-0.6*(1.-0.6)+0.18,0.02],'ko-',ms=10.)
gca().xaxis.set_major_formatter(nullfmt)
gca().yaxis.set_major_formatter(nullfmt)
tight_layout()
if save_figures:
    bovy_plot.bovy_end_print(os.path.join(os.getenv('PAPERSDIR'),'2016-stream-stats','illustrate_perturbations.pdf'))
