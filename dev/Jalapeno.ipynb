# %%
import sys
sys.path.append('/data/jls/streamgap-pepper')
from pepper_calc import *
merged_peri=load_denis_simulation_from_file()
gap_centre_impact = np.array([-13.500000,2.840000,-1.840000,-120.839020,-212.891266,194.766098])
pot = aa.Logarithmic(220.,1.,0.9)

# %% [markdown]
# ## Fixed vel

# %%
bombarded_peri,vv,xd,t = bombard(merged_peri,1,gap_centre_impact,pot,np.ones(3)*100.,M=10**8,sigmab=0.01,tevolve=10000.,deltav=100)
bombard_plot(bombarded_peri,vv,xd,t)
bombard_ft_plot(bombarded_peri)
# Out:
# /opt/ioa/software/python/2.7.8/lib/python2.7/site-packages/numpy/core/numeric.py:474: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
#
# /opt/ioa/software/python/2.7.8/lib/python2.7/site-packages/matplotlib/__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
#
# /opt/ioa/software/python/2.7.8/lib/python2.7/site-packages/numpy/ma/core.py:2720: ComplexWarning: Casting complex values to real discards the imaginary part
#   _data = np.array(data, dtype=dtype, copy=copy, subok=True, ndmin=ndmin)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-a779a8c56be8> in <module>()
# ...

# %%
bombarded_peri,vv,xd,t = bombard(merged_peri,1,gap_centre_impact,pot,np.ones(3)*100.,M=10**7,sigmab=0.01,tevolve=10000.,deltav=100)
bombard_plot(bombarded_peri,vv,xd,t)
bombard_ft_plot(bombarded_peri)

# %%
bombarded_peri,vv,xd,t = bombard(merged_peri,1,gap_centre_impact,pot,np.ones(3)*100.,M=10**6,sigmab=0.01,tevolve=10000.,deltav=100)
bombard_plot(bombarded_peri,vv,xd,t)
bombard_ft_plot(bombarded_peri)

# %% [markdown]
# ## Random vel.

# %%
bombarded_peri,vv,xd,t = bombard(merged_peri,1,gap_centre_impact,pot,np.ones(3)*150.,M=10**8,sigmab=0.01,tevolve=10000.,deltav=None)
bombard_plot(bombarded_peri,vv,xd,t)
bombard_ft_plot(bombarded_peri)

# %%
bombarded_peri,vv,xd,t = bombard(merged_peri,1,gap_centre_impact,pot,np.ones(3)*150.,M=10**7,sigmab=0.01,tevolve=10000.,deltav=None)
bombard_plot(bombarded_peri,vv,xd,t)
bombard_ft_plot(bombarded_peri)

# %%
bombarded_peri,vv,xd,t = bombard(merged_peri,1,gap_centre_impact,pot,np.ones(3)*150.,M=10**6,sigmab=0.01,tevolve=10000.,deltav=False)
bombard_plot(bombarded_peri,vv,xd,t)
bombard_ft_plot(bombarded_peri)

# %%
bombarded_peri,vv,xd,t = bombard(merged_peri,10,gap_centre_impact,pot,np.ones(3)*150.,M=10**7,sigmab=0.01,tevolve=10000.,deltav=False)
bombard_plot(bombarded_peri,vv,xd,t)
bombard_ft_plot(bombarded_peri)

# %%
bombarded_peri,vv,xd,t = bombard(merged_peri,100,gap_centre_impact,pot,np.ones(3)*150.,M=10**6,sigmab=0.01,tevolve=10000.,deltav=False)
bombard_plot(bombarded_peri,vv,xd,t)
bombard_ft_plot(bombarded_peri)
# Out:
# /opt/ioa/software/python/2.7.8/lib/python2.7/site-packages/numpy/core/numeric.py:462: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
